# %%
from dotenv import load_dotenv, find_dotenv; load_dotenv(find_dotenv(), override=True)

from run_many_sessions_multi import run_many_sessions

# OpenAI (default)
run_many_sessions(n_sessions=1, model="gpt-5.2", base_seed=None)

# # Claude
# run_many_sessions(n_sessions=1, model="claude:claude-sonnet-4-6", base_seed=None)

# # DeepSeek (OpenAI-compatible)
# run_many_sessions(n_sessions=100, model="deepseek:deepseek-chat", base_seed=None)
# Out:
# ...
# [2026-02-20 18:56:50] Starting run_many_sessions()
# Target sessions: 1
# Output root: /Users/andyzhang349/Desktop/Dissertation/outputs_by_model/gpt-5.2/n1
# Model: gpt-5.2
# Base seed: None
# Resume enabled: True
# ...
#
# ----------------------------------------------------------------------
# [2026-02-20 18:56:50] ▶️  Running session 000/000 | seed=None | model=gpt-5.2
# Output folder: /Users/andyzhang349/Desktop/Dissertation/outputs_by_model/gpt-5.2/n1/session_000
# ✅ Saved intermediate files:
#  - outputs_by_model/gpt-5.2/n1/session_000/scenarios.json
#  - outputs_by_model/gpt-5.2/n1/session_000/prompts.json
#  - outputs_by_model/gpt-5.2/n1/session_000/responses.json
#  - outputs_by_model/gpt-5.2/n1/session_000/scores.json
# [2026-02-20 18:56:52] ✅ Session 000 complete
# Time used: 1.74 seconds | Avg (completed sessions): 1.74 seconds
# Saved scores: /Users/andyzhang349/Desktop/Dissertation/outputs_by_model/gpt-5.2/n1/session_000/scores.json
# ...
